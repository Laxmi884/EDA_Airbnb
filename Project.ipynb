# %% [markdown]
# <a href="https://colab.research.google.com/github/Laxmi884/EDA_Airbnb/blob/V1/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA on AirBNB dataset
# ##### **Contribution**    - Individual
# ##### **Name**            - Laxmikant Mukkawar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project involves an exploratory data analysis (EDA) of Airbnb listings in New York City for 2019. The goal of the analysis is to uncover key insights into pricing patterns, host behavior, and geographical trends that can assist stakeholders in optimizing their business strategies.
#
# The dataset consists of various features, including listing prices, host information, geographical location (latitude and longitude), room types, availability, and review metrics. By analyzing this data, we aim to answer several business-critical questions:
#
# - What are the price distribution patterns across different neighborhoods and room types?
# - Are there geographical clusters of high or low prices in the city?
# - How does the number of listings affect host activity in terms of reviews and availability?
# - What is the relationship between the number of reviews, price, and availability of listings?
#
# ## Key Insights:
# - ### Price Distribution:
# The analysis revealed that certain neighborhoods (e.g., Manhattan) tend to have higher average prices for listings, especially for entire apartments/homes. Other neighborhoods, such as parts of Brooklyn, have lower-priced listings, particularly for shared and private rooms.
# - ### Host Activity:
# Hosts with fewer listings tend to receive more reviews, suggesting a more personalized or dedicated hosting approach. There is no strong correlation between the number of listings a host manages and the availability of their listings.
# - ### Review Trends:
# Listings with higher availability do not necessarily receive more reviews per month. Pricing also does not have a clear linear relationship with the number of reviews—while some expensive listings do receive many reviews, others receive few, suggesting that factors other than price (e.g., location, service quality) influence review volume.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Laxmi884/EDA_Airbnb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count'
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %%
#checking duplicates for each column 
for col in df.columns:
    print(f"Duplicates in {col} - {df[col].duplicated().sum()}")
# Out:
# Duplicates in id - 0
# Duplicates in name - 989
# Duplicates in host_id - 11438
# Duplicates in host_name - 37442
# Duplicates in neighbourhood_group - 48890
# Duplicates in neighbourhood - 48674
# Duplicates in latitude - 29847
# Duplicates in longitude - 34177
# Duplicates in room_type - 48892
# Duplicates in price - 48221
# Duplicates in minimum_nights - 48786
# Duplicates in number_of_reviews - 48501
# Duplicates in last_review - 47130
# Duplicates in reviews_per_month - 47957
# Duplicates in calculated_host_listings_count - 48848
# Duplicates in availability_365 - 48529

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10,6))
plt.bar(df.columns,df.isnull().sum())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Dataset has 16 columns and 48895 enteries. Most of the columns don't have any null values except columns 'last_review' and 'reviews_per_month' they have 10052 null values and except these 2 columns, 'name' and 'host_name' also have some null values that are very nominal i.e 16 and 21 individually.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
column_names = list(df.columns)
column_names
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
df.describe()['price']
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
# finding average price of all unique listings
df[df['host_id'].isin(df['host_id'].unique())]['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# From above we can say that the mean price of the listing is 152.72

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# ## Converting data type of date columns to datetime datatype

# %%
# Write your code to make your dataset analysis ready.
#converting the date column to datetime datatype
df.loc[~df['last_review'].isnull(),'last_review'] = df.loc[~df['last_review'].isnull(),'last_review'].apply(lambda x: pd.to_datetime(x,format='%Y-%m-%d'))

#this can be done using the below method as well
#df['last_review'] = pd.to_datetime(df['last_review'],format='%Y-%m-%d',error = 'coerce')

# %% [markdown]
# ## Geting most popular room types

# %% [markdown]
# Straighforward method

# %%
room_type_pop = df['room_type'].value_counts().reset_index().iloc[df['room_type'].value_counts().reset_index()['count'].idxmax()]
print(f"The room type that's most popular is {room_type_pop['room_type']} with {room_type_pop['count']} entries")
# Out:
# The room type that's most popular is Entire home/apt with 25409 entries

# %% [markdown]
# Method with a function and incase there are multiple room types with same booking amounts

# %%
def most_pop_room(df):
    # Count occurrences of each room type
    count_df = df['room_type'].value_counts().reset_index()
    count_df.columns = ['room_type', 'count']  # Renaming columns for better readability

    # Find the maximum count of bookings
    max_value = count_df['count'].max()

    # Get all room types with the max booking count
    most_popular_rooms = count_df[count_df['count'] == max_value]

    # Return as a dictionary
    result = dict(zip(most_popular_rooms['room_type'], most_popular_rooms['count']))

    return result

# Example usage
a = most_pop_room(df)

if len(a) > 1:
    print("There are multiple room types with the same preference. They are as follows:")
    for room_type, count in a.items():
        print(f"Room type - {room_type}, No. of times booked - {count}")
else:
    room_type, count = list(a.items())[0]
    print(f"The most popular room type is {room_type} with number of times it was booked as {count}")
# Out:
# The most popular room type is Entire home/apt with number of times it was booked as 25409

# %% [markdown]
# Ftom the above analysis we can conclude that yes Private rooms are popular but rooms having categorgy as ' Entire home/apt' are more popular than private rooms not by much but slightly.

# %%
neighbourhood_pop = df['neighbourhood_group'].value_counts().reset_index().iloc[df['neighbourhood_group'].value_counts().reset_index()['count'].idxmax()]

# %%
print(f"The neighbourhood group that's most popular is {neighbourhood_pop['neighbourhood_group']} with {neighbourhood_pop['count']} entries")
# Out:
# The neighbourhood group that's most popular is Manhattan with 21661 entries

# %%
def most_pop_neighbourhood(df):
    # Count occurrences of each neighbourhood and reset the index for easy handling
    count_df = df['neighbourhood_group'].value_counts()

    # Find the maximum count directly
    max_value = count_df.max()

    # Filter the neighbourhoods with the maximum count and convert them into a dictionary
    result = count_df[count_df == max_value].to_dict()

    return result

# Example usage
pop_neighbourhood = most_pop_neighbourhood(df)

if len(pop_neighbourhood) > 1:
    print("There are multiple neighbourhoods with the same preference. They are as follows:")
    for neighbourhood, count in pop_neighbourhood.items():
        print(f"Neighbourhood - {neighbourhood}, No. of times booked - {count}")
else:
    neighbourhood, count = list(pop_neighbourhood.items())[0]
    print(f"The most popular neighbourhood is {neighbourhood} with number of times it was booked as {count}")
# Out:
# The most popular neighbourhood is Manhattan with number of times it was booked as 21661

# %% [markdown]
# ## Price distribution analysis

# %%
#Identifying the most expensive neighbourhood
df.groupby('neighbourhood_group')['price'].mean().sort_values(ascending = False)
# Out:
# neighbourhood_group
# Manhattan        196.875814
# Brooklyn         124.383207
# Staten Island    114.812332
# Queens            99.517649
# Bronx             87.496792
# Name: price, dtype: float64

# %%
#check for outliers in price column 

sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
#Filter out the outliers

Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
df_without_outliers = df[(df['price'] >= (Q1 - 1.5 * IQR)) & (df['price'] <= (Q3 + 1.5 * IQR))]

print(f"Number of rows before removing outliers: {len(df)}")    
print(f"Number of rows after removing outliers: {len(df_without_outliers)}")
print(df_without_outliers.shape)
sns.boxplot(df_without_outliers['price'])
# Out:
# Number of rows before removing outliers: 48895
# Number of rows after removing outliers: 45923
# (45923, 16)
# <Axes: ylabel='price'>

# %% [markdown]
# ## Identifying most popular room in each neighbourhood

# %%
# group data on neighbourhood and room type to analyze popular room in each neighbourhood
df_without_outliers.groupby(['neighbourhood_group', 'room_type']).size().unstack()
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                            363           648           59
# Brooklyn                        8942         10062          411
# Manhattan                      11294          7747          465
# Queens                          2022          3351          194
# Staten Island                    168           188            9

# %%
df_without_outliers.groupby(['neighbourhood_group', 'room_type']).size().unstack().plot(kind='bar', stacked=False)
# Out:
# <Axes: xlabel='neighbourhood_group'>

# %%
df_without_outliers.groupby(['neighbourhood_group', 'room_type']).size().unstack().loc[['Brooklyn','Manhattan']]
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Brooklyn                        8942         10062          411
# Manhattan                      11294          7747          465

# %% [markdown]
# ## Analyze prices of rooms according to Neighbourhood and room type

# %%
# Group data on neighbourhood and room type to analyze prizes in each neighbourhood according to each room type
print(df_without_outliers.groupby(['neighbourhood_group', 'room_type'])['price'].mean().unstack())
df_without_outliers.groupby(['neighbourhood_group', 'room_type'])['price'].mean().unstack().plot(kind='bar', stacked=True)
plt.title('Room Type Popularity Across Neighbourhood Groups')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Average Price')
plt.show()
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     112.195592     60.595679    47.254237
# Brooklyn                  148.202080     70.283443    48.036496
# Manhattan                 181.688596     98.057700    75.939785
# Queens                    131.328388     65.732319    46.989691
# Staten Island             121.089286     62.292553    57.444444

# %%
df_without_outliers.groupby(['neighbourhood_group', 'room_type'])['price'].mean().unstack()
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     112.195592     60.595679    47.254237
# Brooklyn                  148.202080     70.283443    48.036496
# Manhattan                 181.688596     98.057700    75.939785
# Queens                    131.328388     65.732319    46.989691
# Staten Island             121.089286     62.292553    57.444444

# %%
mean_prices = df_without_outliers.groupby(['neighbourhood_group', 'room_type'])['price'].mean().unstack()
mean_prices.plot(kind='bar', figsize=(10, 6), width=0.8)
plt.title('Average Price by Neighbourhood Group and Room Type')
plt.ylabel('Average Price (USD)')
plt.xticks(rotation=45)
plt.show()

# %%
#Calculate summary statistics such as the mean, median, and range of prices within each group.
grop= df_without_outliers.groupby(['neighbourhood_group', 'room_type'])['price'].describe()
grop
# Out:
#                                        count        mean        std   min  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    375.0  121.480000  72.801679  28.0
#                     Private room       648.0   60.595679  31.967383   0.0
#                     Shared room         59.0   47.254237  30.579232  20.0
# Brooklyn            Entire home/apt   9325.0  158.278928  75.666989   0.0
#                     Private room     10088.0   71.113402  36.704504   0.0
#                     Shared room        412.0   48.890777  41.877590   0.0
# Manhattan           Entire home/apt  12416.0  201.285680  86.978279   0.0
#                     Private room      7865.0  102.435092  59.708532  10.0
#                     Shared room        475.0   82.334737  63.164506  10.0
# Queens              Entire home/apt   2073.0  137.880367  70.973717  10.0
#                     Private room      3363.0   66.892061  36.281297  10.0
# ...

# %%
grop['mean'].unstack().loc[['Brooklyn','Manhattan']]
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Brooklyn                  158.278928     71.113402    48.890777
# Manhattan                 201.285680    102.435092    82.334737

# %%
#Create visualizations to compare price distributions between different neighbourhoods and room types.
mean_prices = grop['mean'].unstack()

plt.figure(figsize=(10, 6))
sns.heatmap(mean_prices, annot=True, cmap='viridis', fmt=".2f", cbar=True)
plt.title('Average Price by Neighbourhood Group and Room Type')
plt.xlabel('Room Type')
plt.ylabel('Neighbourhood Group')
plt.show()

# %% [markdown]
# ## Analyzing Host Activity: Are Hosts with Multiple Listings more active
# Assumptions : Higher reviews may indicate higher activity

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# ...

# %%
## Analyzing host activity: Are hosts with multiple listing more active.
# Group by calculated_host_listings_count and calculate average reviews and availability
host_activity = df_without_outliers.groupby('calculated_host_listings_count').agg({
    'number_of_reviews': 'mean',
    'availability_365': 'mean'
}).reset_index()

# Display the host activity data
host_activity.sort_values(['number_of_reviews', 'availability_365', 'calculated_host_listings_count'], ascending=False)
# Out:
#     calculated_host_listings_count  number_of_reviews  availability_365
# 10                              11          42.835294        239.529412
# 3                                4          38.495905        177.507818
# 4                                5          37.601494        199.341220
# 2                                3          36.514139        162.044436
# 1                                2          35.377799        125.428057
# 11                              12          29.272059        206.294118
# 5                                6          29.162921        218.102996
# 12                              13          26.138211        263.097561
# 9                               10          22.162437        271.644670
# 0                                1          20.864076         75.156577
# 7                                8          20.789340        223.357868
# 14                              15          20.770270        237.324324
# ...

# %%
# Scatter plot for number of reviews vs. number of listings
plt.figure(figsize=(10, 6))
sns.scatterplot(x='calculated_host_listings_count', y='number_of_reviews', data=df_without_outliers)
plt.title('Number of Reviews vs. Number of Listings')
plt.xlabel('Number of Listings')
plt.ylabel('Number of Reviews')
plt.show()

# Scatter plot for availability vs. number of listings
plt.figure(figsize=(10, 6))
sns.scatterplot(x='calculated_host_listings_count', y='availability_365', data=df_without_outliers)
plt.title('Availability vs. Number of Listings')
plt.xlabel('Number of Listings')
plt.ylabel('Availability (days)')
plt.show()

# %%
# Create categories for hosts with different ranges of listings
df['listings_category'] = pd.cut(df['calculated_host_listings_count'],
                                                  bins=[0, 1, 5, 10, float('inf')],
                                                  labels=['1 listing', '2-5 listings', '6-10 listings', '10+ listings'])

# Group by these categories and calculate mean reviews and availability
host_activity_by_category = df.groupby('listings_category').agg({
    'number_of_reviews': 'mean',
    'availability_365': 'mean'
}).reset_index()

print(host_activity_by_category)
# Out:
#   listings_category  number_of_reviews  availability_365
# 0         1 listing          20.417856         78.900907
# 1      2-5 listings          35.336640        147.751950
# 2     6-10 listings          22.126845        227.124658
# 3      10+ listings           7.127064        272.131446
# /var/folders/9c/1mr24qp56ds1jxs6364lczbw0000gn/T/ipykernel_36362/2016328173.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   host_activity_by_category = df.groupby('listings_category').agg({

# %%
# Calculate the correlation between number of listings and number of reviews
correlation_reviews = df[['calculated_host_listings_count', 'number_of_reviews']].corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_reviews, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation between Host Listings and Reviews')
plt.show()

# %% [markdown]
# Insights: Hosts with less number of listing have more reviews. The availablity has no coorelation with number of listings.

# %% [markdown]
# ## Review Trends: What Is the Relationship Between the Number of Reviews and Price, or Between Reviews Per Month and Availability?

# %%
# Scatter plot for price vs number of reviews
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price', y='number_of_reviews', data=df_without_outliers)
plt.title('Number of Reviews vs. Price')
plt.xlabel('Price (USD)')
plt.ylabel('Number of Reviews')
plt.show()

# Calculate the correlation between price and number of reviews
correlation_price_reviews = df_without_outliers[['price', 'number_of_reviews']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_price_reviews, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation between Price and Reviews')
plt.show()

# %% [markdown]
# There is no strong evidence that higher number of reviews have any direct relation with price

# %% [markdown]
# ## Identifying coorelation between all variables with price

# %%
# setiing price column at last
columns =list(df_without_outliers.columns)
columns.remove('price')
columns.append('price')
df_without_outliers = df_without_outliers[columns]
df_without_outliers.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  minimum_nights  number_of_reviews          last_review  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code 
#distribution plot for column price

sns.histplot(df['price'],bins=100)
# Set the title and labels
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
