# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA on AirBNB dataset
# ##### **Contribution**    - Individual
# ##### **Name**            - Laxmikant Mukkawar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project involves an exploratory data analysis (EDA) of Airbnb listings in New York City for 2019. The goal of the analysis is to uncover key insights into pricing patterns, host behavior, and geographical trends that can assist stakeholders in optimizing their business strategies.
#
# The dataset consists of various features, including listing prices, host information, geographical location (latitude and longitude), room types, availability, and review metrics. By analyzing this data, we aim to answer several business-critical questions:
#
# - What are the price distribution patterns across different neighborhoods and room types?
# - Are there geographical clusters of high or low prices in the city?
# - How does the number of listings affect host activity in terms of reviews and availability?
# - What is the relationship between the number of reviews, price, and availability of listings?
#
# ## Key Insights:
# - ### Price Distribution:
# The analysis revealed that certain neighborhoods (e.g., Manhattan) tend to have higher average prices for listings, especially for entire apartments/homes. Other neighborhoods, such as parts of Brooklyn, have lower-priced listings, particularly for shared and private rooms.
# - ### Host Activity:
# Hosts with fewer listings tend to receive more reviews, suggesting a more personalized or dedicated hosting approach. There is no strong correlation between the number of listings a host manages and the availability of their listings.
# - ### Review Trends:
# Listings with higher availability do not necessarily receive more reviews per month. Pricing also does not have a clear linear relationship with the number of reviews—while some expensive listings do receive many reviews, others receive few, suggesting that factors other than price (e.g., location, service quality) influence review volume.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Laxmi884/EDA_Airbnb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The New York City Airbnb market is highly competitive, with thousands of listings spread across different neighborhoods, room types, and price ranges. Hosts and property managers face the challenge of setting optimal prices, maintaining high availability, and attracting positive reviews in a crowded marketplace.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary objective of this analysis is to provide Airbnb hosts, property managers, and potential investors with data-driven insights to improve the performance of their listings in New York City. Specifically, the analysis aims to help hosts achieve the following:
#
# 1. Optimize Pricing: By analyzing price trends across different neighborhoods and room types, the objective is to help hosts set competitive prices that maximize both occupancy and revenue. Understanding how prices vary by location, room type, and other factors will enable hosts to position their listings more effectively in the market.
# 2. Increase Listing Visibility and Engagement: Hosts can increase guest engagement by understanding the relationship between reviews and factors like price, availability, and location. The analysis will help identify strategies that drive more reviews and guest satisfaction, leading to higher visibility on the Airbnb platform.
# 3. Improve Availability Management: The analysis will help hosts manage availability more efficiently by exploring how the number of days a listing is available throughout the year affects booking rates and reviews. This can lead to better resource allocation and potentially higher occupancy rates.
# 4. Identify High-Demand Locations: By identifying geographical clusters where demand is high (based on pricing, reviews, and availability), the objective is to help hosts target neighborhoods with strong rental demand. This can inform decisions about where to list new properties or where to focus marketing efforts.
# 5. Support Business Growth: For hosts with multiple listings, the analysis provides insights into how the number of listings affects overall performance, such as reviews and availability. These insights will help hosts scale their operations efficiently while maintaining a high level of guest satisfaction.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv('Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count'
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 0

# %%
#checking duplicates for each column 
for col in df.columns:
    print(f"Duplicates in {col} - {df[col].duplicated().sum()}")
# Out:
# Duplicates in id - 0
# Duplicates in name - 989
# Duplicates in host_id - 11438
# Duplicates in host_name - 37442
# Duplicates in neighbourhood_group - 48890
# Duplicates in neighbourhood - 48674
# Duplicates in latitude - 29847
# Duplicates in longitude - 34177
# Duplicates in room_type - 48892
# Duplicates in price - 48221
# Duplicates in minimum_nights - 48786
# Duplicates in number_of_reviews - 48501
# Duplicates in last_review - 47130
# Duplicates in reviews_per_month - 47957
# Duplicates in calculated_host_listings_count - 48848
# Duplicates in availability_365 - 48529

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Dataset has 16 columns and 48895 enteries. Most of the columns don't have any null values except columns 'last_review' and 'reviews_per_month' they have 10052 null values and except these 2 columns, 'name' and 'host_name' also have some null values that are very nominal i.e 16 and 21 individually.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
column_names = list(df.columns)
column_names
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365']

# %% [markdown]
# ### Variables Description

# %%
# Dataset Describe
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ##### We observe that the minimum value of price is zero which can't be true. We need to fix this
# - Categorical Variables: neighbourhood_group, neighbourhood, room_type
# - Numerical Variables: price, minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365, latitude, longitude
# - Text Variables: name, host_name
# - Date Variables: last_review

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# #### Converting data type of date columns to datetime datatype

# %%
#converting the date column to datetime datatype
df['last_review'] = pd.to_datetime(df['last_review'],format='%Y-%m-%d',errors = 'coerce')

#this can be done using the below method as well

#df.loc[~df['last_review'].isnull(),'last_review'] = df.loc[~df['last_review'].isnull(),'last_review'].apply(lambda x: pd.to_datetime(x,format='%Y-%m-%d'))

# %% [markdown]
# #### Checking if its coverted correctly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### function to identify most popular room type

# %%
def most_pop_room(df):
    # Count occurrences of each room type
    count_df = df['room_type'].value_counts().reset_index()
    count_df.columns = ['room_type', 'count']  # Renaming columns for better readability

    # Find the maximum count of bookings
    max_value = count_df['count'].max()

    # Get all room types with the max booking count
    most_popular_rooms = count_df[count_df['count'] == max_value]

    # Return as a dictionary
    result = dict(zip(most_popular_rooms['room_type'], most_popular_rooms['count']))

    return result

# Example usage
a = most_pop_room(df)

if len(a) > 1:
    print("There are multiple room types with the same preference. They are as follows:")
    for room_type, count in a.items():
        print(f"Room type - {room_type}, No. of times booked - {count}")
else:
    room_type, count = list(a.items())[0]
    print(f"The most popular room type is {room_type} with number of times it was booked as {count}")
# Out:
# The most popular room type is Entire home/apt with number of times it was booked as 25409

# %% [markdown]
# #### Function to identify most popular neighbourhood

# %%
def most_pop_neighbourhood(df):
    # Count occurrences of each neighbourhood and reset the index for easy handling
    count_df = df['neighbourhood_group'].value_counts()

    # Find the maximum count directly
    max_value = count_df.max()

    # Filter the neighbourhoods with the maximum count and convert them into a dictionary
    result = count_df[count_df == max_value].to_dict()

    return result

# Example usage
pop_neighbourhood = most_pop_neighbourhood(df)

if len(pop_neighbourhood) > 1:
    print("There are multiple neighbourhoods with the same preference. They are as follows:")
    for neighbourhood, count in pop_neighbourhood.items():
        print(f"Neighbourhood - {neighbourhood}, No. of times booked - {count}")
else:
    neighbourhood, count = list(pop_neighbourhood.items())[0]
    print(f"The most popular neighbourhood is {neighbourhood} with number of times it was booked as {count}")
# Out:
# The most popular neighbourhood is Manhattan with number of times it was booked as 21661

# %% [markdown]
# #### When we inspected the dataframe we observed that the minimum value in price is 0 which can't be true so we will fix this.

# %%
#replacing price values where it is zero with mean value
df['price'] = df['price'].replace(0,df['price'].mean())

# %% [markdown]
# #### Checking if zero's are replaced correctly for price column

# %%
df['price'].describe()
# Out:
# count    48895.000000
# mean       152.755045
# std        240.143242
# min         10.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# #### Adding a new column named listing category. This will help us categories the listings count and perform analysis later

# %%
df['listings_category'] = pd.cut(df['calculated_host_listings_count'],
                                                  bins=[0, 1, 5, 10, float('inf')],
                                                  labels=['1 listing', '2-5 listings', '6-10 listings', '10+ listings'])

# %% [markdown]
# #### getting skewness and Kurtosis for price column

# %%
# getting skewness and kurtosis for price column
print(f'The skewness of price is: {df['price'].skew()}')
print(f'The kurtosis of price is: {df['price'].kurt()}')
# Out:
# The skewness of price is: 19.12117771378404
# The kurtosis of price is: 585.7690535466286

# %% [markdown]
# From the above results of skewness of kurtosis we can infer that the data is positively skeweed i.e the data has a long right tail. And from kurtosis value can say that there are many outliers

# %% [markdown]
# #### Removing outliers and creating new dataframe without outliers

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
df_without_outliers = df[(df['price'] >= (Q1 - 1.5 * IQR)) & (df['price'] <= (Q3 + 1.5 * IQR))]

print(f"Number of rows before removing outliers: {len(df)}")    
print(f"Number of rows after removing outliers: {len(df_without_outliers)}")
print(df_without_outliers.shape)
# Out:
# Number of rows before removing outliers: 48895
# Number of rows after removing outliers: 45923
# (45923, 17)

# %% [markdown]
# #### Analyzing host activity: Are Hosts that have multiple listing are more active ( More reviews indicate more activity by hosts)

# %%
# Group by calculated_host_listings_count and calculate average reviews and availability
host_activity = df_without_outliers.groupby('calculated_host_listings_count').agg({
    'number_of_reviews': 'mean',
    'availability_365': 'mean'
}).reset_index()

# Display the host activity data
host_activity.sort_values(['number_of_reviews', 'availability_365', 'calculated_host_listings_count'], ascending=False)
# Out:
#     calculated_host_listings_count  number_of_reviews  availability_365
# 10                              11          42.835294        239.529412
# 3                                4          38.495905        177.507818
# 4                                5          37.601494        199.341220
# 2                                3          36.514139        162.044436
# 1                                2          35.377799        125.428057
# 11                              12          29.272059        206.294118
# 5                                6          29.162921        218.102996
# 12                              13          26.138211        263.097561
# 9                               10          22.162437        271.644670
# 0                                1          20.864076         75.156577
# 7                                8          20.789340        223.357868
# 14                              15          20.770270        237.324324
# ...

# %% [markdown]
# From the above dataframe we can infer that more the number of listings less number of listings have more reviews. We will understand this visualy later.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# In this project, several data wrangling techniques were employed to clean and prepare the dataset for analysis. First, the last_review column was converted to a datetime format to facilitate time-based analysis of the reviews. Missing values were handled by using errors='coerce' to convert invalid date formats to NaT (Not a Time). For the room type analysis, the most popular room type was determined by counting occurrences of each room type. The function revealed that if multiple room types shared the highest count, they were reported together; otherwise, the single most popular room type was identified.
#
# Similarly, the most popular neighbourhood group was identified by counting the occurrences of listings in each neighbourhood group. For the price variable, listings with a price of zero were replaced by the mean price to avoid skewing the analysis with invalid price data.
#
# To further clean the data, hosts were categorized based on the number of listings they managed using the pd.cut() function, which grouped them into categories: 1 listing, 2–5 listings, 6–10 listings, and 10+ listings. Outliers in the price column were removed using the interquartile range (IQR) method, which eliminated listings with prices outside of 1.5 times the IQR from the first and third quartiles.
#
# Lastly, host activity was analyzed by grouping hosts based on the number of listings and calculating the average number of reviews and availability for each group. This provided insights into how host behavior changes with the number of listings they manage. The results indicated that hosts with fewer listings tend to receive more reviews on average, suggesting a higher level of engagement or service quality for these hosts. However, availability did not show a strong correlation with the number of listings.
#
# These manipulations and analyses offer valuable insights into listing prices, host activity, and popular locations, which can help Airbnb hosts optimize their listings for better performance and guest engagement.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code 
#distribution plot for column price

sns.histplot(df['price'],bins=50,kde=True)
# Set the title and labels
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram (created using sns.histplot()) was chosen because it is the most suitable chart for visualizing the distribution of a continuous variable like price. The histogram allows us to see the frequency of different price ranges, making it easy to identify the distribution shape and any potential outliers. Since price is a numerical variable, this chart type helps in understanding its spread and concentration across different ranges.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The distribution of prices is highly right-skewed, meaning that most listings are concentrated at the lower end of the price spectrum, while a small number of listings have very high prices (long tail to the right).
# - The majority of the listings have prices below $500, with an overwhelming number of them priced under $200.
# - There are a few outliers where the price goes up to $10,000, but these are extremely rare.
# - This insight suggests that lower-priced listings are much more common in the dataset, and there might be only a few high-end luxury properties skewing the price range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights gained from this distribution can help hosts and property managers in pricing strategy:
# - For most hosts, setting a competitive price within the lower-to-mid price range (where most listings lie) will likely result in better visibility and more bookings, given that most users are likely searching in this range.
# - For high-end properties, the small number of listings priced significantly higher suggests that luxury listings are rare. This could present an opportunity to target a niche market, offering premium experiences at higher prices if there is demand for exclusive stays.
# - Additionally, understanding that the market is saturated with lower-priced listings allows property managers to better position and differentiate higher-priced listings with value-added services or amenities.

# %% [markdown]
# #### Chart 2

# %%
# Chart - 2 visualization code
# Identifying outliers 

sns.boxplot(df['price'])
plt.title('Identifying Outliers')
# Out:
# Text(0.5, 1.0, 'Identifying Outliers')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen to identify outliers in the price distribution. Box plots are particularly effective in showing the spread and skewness of the data, along with the range where most data points lie (interquartile range, or IQR). The box plot clearly shows the median, quartiles, and any extreme values (outliers) beyond the "whiskers" of the plot, making it ideal for detecting outliers in the dataset, which is critical in understanding the variability in prices.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - The box plot reveals that most Airbnb listings have prices that fall within a relatively small range (as seen by the compact box in the lower part of the chart).
# - However, there are numerous outliers—listings with extremely high prices, going up to $10,000. These outliers represent the most expensive luxury listings in the dataset.
# - The median price is low compared to the extreme outliers, and the range of the majority of listings appears to be between $0 to $1,000.
# - These outliers can skew the overall analysis of prices, and identifying them helps in deciding whether to treat or remove them for more accurate insights into typical listings.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive impact

# %% [markdown]
# Yes, these insights are crucial for several reasons:
# - Identifying and handling outliers ensures that business decisions are based on typical listing prices rather than being influenced by a few extreme values.
# - By understanding that there are many high-priced outliers, Airbnb hosts can decide whether they want to compete in the luxury market or focus on more competitively priced listings.
# - For data analysis, removing or adjusting for these outliers ensures that recommendations, such as pricing strategies, are not distorted by the few extreme listings, leading to more accurate and actionable insights.
# - For hosts managing high-end listings, the presence of numerous outliers may indicate a demand for luxury properties, and they can use this insight to market premium services to attract high-paying guests. Conversely, for most hosts, competing at a lower price point may be more feasible given the broader market demand for affordable listings.

# %% [markdown]
# #### Chart 3

# %%
# chart 3 visualization code
# Polting the density plot for price after removing outliers
sns.histplot(df_without_outliers['price'],kde=True)
plt.title('Density Plot of Prices')
plt.xlabel('Price')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart ?

# %% [markdown]
# The density plot (histogram with KDE) was chosen because it allows for a smooth visualization of the distribution of prices after removing outliers. The histogram shows the frequency of prices within different ranges, while the KDE (Kernel Density Estimate) line provides a smoothed curve to highlight the underlying shape of the distribution. This chart helps in understanding the central tendency and spread of prices while clearly identifying the peaks or concentrations of data.

# %% [markdown]
# ##### 2. What are the insights found from the chart ?

# %% [markdown]
# - The chart reveals a bimodal distribution for prices, with two noticeable peaks around $50 to $100 and $150 to $200. This indicates that listings tend to cluster in these price ranges, with many properties priced within those ranges.
# - Most prices are concentrated between $50 and $200, with the largest density of listings priced under $150.
# - There is a rapid decline in density after $200, with very few listings priced above this range, confirming that higher-priced listings are relatively rare in this dataset (after outlier removal).

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, these insights are valuable for pricing and market positioning:
# - Hosts who want to price their listings competitively can aim for the $50 to $150 range, where the bulk of listings are concentrated, ensuring that their properties are in line with market demand.
# - The bimodal nature of the distribution suggests that there might be two main types of listings in terms of pricing—perhaps lower-budget and mid-range properties. Hosts can use this insight to target either segment more effectively based on their listing type and amenities.
# - Understanding that listings priced above $200 are relatively rare (after outlier removal) could help high-end hosts leverage this exclusivity by offering premium services and justifying higher rates.

# %% [markdown]
# #### Chart 4

# %%
# Identify most popular room type 
df_without_outliers.groupby('room_type').size().plot(kind='bar', stacked=False)
plt.xlabel('Room Type')
plt.ylabel('Number of Listings')
plt.title('Number of Listings by Room Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it effectively shows the count of listings for each room type (Entire home/apt, Private room, Shared room). The bar chart allows for easy comparison of the total number of listings across these categories, making it clear which room types are more prevalent in the dataset. Bar charts are ideal for visualizing categorical data, such as room types, and highlighting the frequency distribution.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - Entire home/apartment and private rooms dominate the listings, with almost equal numbers, both having around 20,000+ listings. These two room types make up the vast majority of Airbnb listings.
# - Shared rooms are much less common, accounting for only a small fraction of the overall listings.
# - This suggests that most Airbnb users in New York City are either looking for entire properties or private rooms, while the demand for shared rooms is significantly lower.

# %% [markdown]
# ##### 3.Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, the insights from this chart can positively influence business decisions in the following ways:
# - Hosts: If you're a host considering what type of space to list on Airbnb, this chart suggests that there is a strong demand for both entire homes/apartments and private rooms. These are the most common listings, and likely the most in-demand categories, which means that focusing on offering these types of accommodations could yield better occupancy rates.
# - Market Opportunity: The low number of shared rooms may indicate a potential opportunity for budget-conscious travelers looking for cheaper accommodations. While the demand may be lower for shared rooms, a lack of supply could allow hosts offering shared rooms to target a niche market.
# - Pricing Strategy: Since entire homes and private rooms dominate the market, competition in these categories is likely higher. Therefore, hosts in these categories will need to differentiate their listings through better amenities, reviews, or pricing strategies to stand out from the competition.

# %% [markdown]
# #### Chart 5

# %%
# Identify most popular neighbourhood group and room type
df_without_outliers.groupby(['neighbourhood_group', 'room_type']).size().unstack().plot(kind='bar', stacked=False)
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Listings')
plt.title('Number of Listings by Neighbourhood Group and Room Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1.Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart was chosen because it effectively compares the number of Airbnb listings across different neighbourhood groups and room types. Each neighborhood group is represented on the x-axis, and the different room types (Entire home/apt, Private room, Shared room) are represented by distinct colors. This chart allows for an easy comparison of how listings are distributed by room type within each neighborhood, making it ideal for comparing multiple categories simultaneously.

# %% [markdown]
# ##### 2. What are the insights found from the chart

# %% [markdown]
# - Manhattan and Brooklyn dominate the Airbnb market in terms of the number of listings, with both boroughs having significantly more listings compared to other areas like Queens, Bronx, and Staten Island.
# - Entire home/apt is the most common room type in Manhattan and Brooklyn, which suggests these areas cater to travelers seeking private, fully enclosed accommodations.
# - Private rooms also have a substantial presence, particularly in Brooklyn and Manhattan, which could indicate demand from budget travelers looking for more affordable options.
# - Shared rooms are the least common across all neighborhoods, though they are slightly more represented in Brooklyn and Manhattan compared to other boroughs.
# - Queens shows a moderate number of listings, while Bronx and Staten Island have significantly fewer listings overall, with the majority of those being either private rooms or entire homes.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, these insights can create a positive business impact by helping hosts and property managers better understand market dynamics:
# - In neighborhoods like Brooklyn and Manhattan, where there is already a large supply of entire homes and private rooms, new hosts might want to consider niche offerings (such as unique shared spaces or premium entire homes) to stand out from the competition.
# - Queens offers a more balanced mix of room types and fewer listings overall, which could present an opportunity for expansion, especially for hosts looking to cater to travelers who may want access to Manhattan but at a lower cost.
# - Bronx and Staten Island have much fewer listings, suggesting they may be underdeveloped markets with potential for growth if there is sufficient demand. Hosts could target these neighborhoods with strategic pricing and marketing.
# - For property managers, understanding the room type demand per borough allows them to tailor their marketing strategies. For example, marketing entire homes in Manhattan and Brooklyn where these are in high demand or promoting shared rooms for budget travelers in neighborhoods where they are still less common.

# %% [markdown]
# #### Chart 6

# %%
mean_prices = df_without_outliers.groupby(['neighbourhood_group', 'room_type'])['price'].mean().unstack()
mean_prices.plot(kind='bar', figsize=(10, 6), width=0.8)
plt.title('Average Price by Neighbourhood Group and Room Type')
plt.ylabel('Average Price (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A grouped bar chart was chosen because it effectively compares the average price of Airbnb listings by neighbourhood group and room type. This chart type is ideal for showing the variation in average prices across different boroughs (neighbourhood groups) while breaking it down further by room type (Entire home/apt, Private room, Shared room). It makes it easy to compare how each room type is priced within and across different neighborhoods.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - Manhattan has the highest average prices across all room types, with Entire home/apartment listings being the most expensive, averaging around $175+.
# - Brooklyn follows Manhattan, though prices are lower. The average price for an entire home/apartment is still high, around $150, while private rooms and shared rooms are priced significantly lower.
# - Bronx, Queens, and Staten Island have much lower average prices across all room types, especially for shared rooms, which have the lowest averages in these areas.
# - The price hierarchy across room types remains consistent across boroughs, with entire homes being the most expensive, followed by private rooms, and shared rooms being the least expensive.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, the insights from this chart can help Airbnb hosts and property managers in various ways:
# - Pricing Strategy: Hosts in Manhattan can charge significantly higher rates compared to other boroughs, especially for entire homes. In contrast, hosts in areas like Bronx, Queens, or Staten Island should adopt a more competitive pricing strategy since the market in these boroughs is much more price-sensitive.
# - Target Audience: The data suggests that hosts offering shared rooms should target budget-conscious travelers, particularly in areas like the Bronx, Queens, and Staten Island where the demand for lower-cost options may be higher. On the other hand, entire homes and private rooms in Manhattan and Brooklyn cater to travelers who are willing to pay more for privacy and location.
# - Expansion Opportunities: For hosts looking to expand their listings, this chart highlights that there might be opportunities in less saturated, lower-priced areas like Staten Island or Queens, where offering competitively priced entire homes or private rooms could attract demand while still maintaining profitability.

# %% [markdown]
# #### Chart 7

# %%
#Calculate summary statistics such as the mean, median, and range of prices within each group.
grop= df_without_outliers.groupby(['neighbourhood_group', 'room_type'])['price'].describe()
grop
# Out:
#                                        count        mean        std   min  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    363.0  112.195592  52.059016  28.0
#                     Private room       648.0   60.831359  32.082709  10.0
#                     Shared room         59.0   47.254237  30.579232  20.0
# Brooklyn            Entire home/apt   8942.0  148.219159  58.383329  10.0
#                     Private room     10062.0   70.374510  32.865027  10.0
#                     Shared room        411.0   48.779663  38.707219  15.0
# Manhattan           Entire home/apt  11294.0  181.702118  62.020335  10.0
#                     Private room      7747.0   98.057700  48.138409  10.0
#                     Shared room        465.0   75.939785  45.873193  10.0
# Queens              Entire home/apt   2022.0  131.328388  58.036911  10.0
#                     Private room      3351.0   65.732319  30.631410  10.0
# ...

# %%
#Create visualizations to compare price distributions between different neighbourhoods and room types.
mean_prices = grop['mean'].unstack()

plt.figure(figsize=(10, 6))
sns.heatmap(mean_prices, annot=True, cmap='viridis', fmt=".2f", cbar=True)
plt.title('Average Price by Neighbourhood Group and Room Type')
plt.xlabel('Room Type')
plt.ylabel('Neighbourhood Group')
plt.show()

# %% [markdown]
# ##### 1.Why did you pick the specific chart?

# %% [markdown]
# A heatmap was chosen because it provides a clear and intuitive way to display the average prices for different room types across multiple neighbourhood groups. The heatmap uses colors to indicate the magnitude of values, allowing us to quickly spot patterns and trends across the dataset. It is especially useful for showing numerical data in a matrix format, which makes it easy to compare prices between room types and neighborhoods at the same time.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - Manhattan consistently has the highest average prices across all room types, with entire homes/apartments averaging $181.70, private rooms at $98.06, and shared rooms at $75.94.
# - Brooklyn follows Manhattan, with average prices of $148.22 for entire homes/apartments, $70.37 for private rooms, and $48.78 for shared rooms.
# - Queens and Staten Island have lower average prices compared to Manhattan and Brooklyn, with entire homes/apartments priced around $131.33 and $121.09 respectively. The prices for private and shared rooms in these boroughs are also much lower.
# - Bronx has the lowest prices overall, with the average price of an entire home/apartment being $112.20 and the average price for a private room being $60.83.
# - The color gradient clearly highlights the stark price differences between Manhattan and the other boroughs, particularly for entire homes/apartments.

# %% [markdown]
# ##### 3.Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, these insights will help Airbnb hosts and property managers in making data-driven pricing decisions:
# - Hosts in Manhattan can command the highest prices, especially for entire homes, and can position themselves as premium listings. Knowing that Manhattan listings are more expensive, hosts can justify these prices by offering additional amenities and ensuring high-quality services to attract guests.
# - Hosts in Brooklyn can also capitalize on relatively high prices for entire homes and private rooms while maintaining competitive rates compared to Manhattan.
# - For boroughs like Bronx, Queens, and Staten Island, the lower average prices suggest that these areas cater to more budget-conscious travelers. Hosts in these areas should focus on providing value-for-money accommodations and perhaps offer discounts or unique features to attract guests looking for affordability.
# - Strategic Expansion: Property managers looking to invest in new areas can use this data to decide whether to enter higher-priced markets like Manhattan or capitalize on underserved markets with lower prices like the Bronx or Staten Island.
# - Room Type Differentiation: The price difference between entire homes and private/shared rooms offers room for pricing strategy adjustments. Hosts can price listings based on the type of guest they're targeting—higher-end travelers for entire homes and budget travelers for private or shared rooms.

# %% [markdown]
# #### Chart 8

# %%
# Scatter plot for number of reviews vs. number of listings
plt.figure(figsize=(10, 6))
sns.scatterplot(x='calculated_host_listings_count', y='number_of_reviews', data=df_without_outliers)
plt.title('Number of Reviews vs. Number of Listings')
plt.xlabel('Number of Listings')
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen because it is ideal for visualizing the relationship between two continuous variables—in this case, the number of listings a host has and the number of reviews received. The scatter plot helps in identifying trends, correlations, or patterns between these two variables. It shows the distribution of reviews across hosts with different numbers of listings and can help identify whether there's a significant relationship between host activity and guest engagement.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - The scatter plot shows that hosts with fewer listings (particularly between 0 and 10 listings) tend to receive more reviews. These hosts cluster in the top-left corner of the chart, with several receiving hundreds of reviews.
# - On the other hand, hosts with many listings (more than 50 listings) tend to have fewer reviews per listing. The data points for these hosts are spread along the x-axis with minimal movement along the y-axis, indicating low review counts despite the high number of listings.
# - This pattern suggests that hosts with fewer listings may have more direct interaction with their guests, resulting in higher engagement and more reviews. In contrast, hosts managing a large number of listings may not receive as many reviews per listing, possibly due to more standardized or less personal services.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, these insights can help in shaping strategies for Airbnb hosts and property managers:
# - For Hosts with Fewer Listings: The data shows that hosts with a small number of listings (1–10) receive more reviews, which could indicate more personalized guest experiences or better guest engagement. These hosts could leverage this advantage by continuing to provide high-quality service to generate positive reviews and maintain high visibility on the platform.
# - For Hosts with Many Listings: Hosts managing large portfolios may benefit from focusing on improving guest experience to generate more reviews per listing. Since reviews are an important factor in increasing listing visibility and bookings, these hosts could implement strategies to encourage reviews, such as offering incentives or improving communication.
# - Business Growth Consideration: Property managers looking to expand should consider that while having more listings can increase overall revenue, it might reduce the personal interaction with guests, leading to fewer reviews per listing. Balancing growth with guest satisfaction will be key to maintaining high ratings and guest engagement across multiple properties.

# %% [markdown]
# #### Chart 9

# %%
avg_price_neighborhood = df_without_outliers.groupby('neighbourhood')['price'].mean().reset_index()
avg_price_neighborhood = avg_price_neighborhood.sort_values(by='price', ascending=False)
top_neighborhoods = avg_price_neighborhood.head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood', y='price', data=top_neighborhoods)
plt.title('Top Neighborhoods in NYC by Average Price/Day')
plt.xlabel('Neighborhood')
plt.ylabel('Average Price/Day')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected because it is an effective way to compare the average price per day across different neighborhoods in New York City. Bar charts are ideal for displaying and comparing discrete categories (in this case, neighborhoods) and their corresponding numerical values (average price per day). It makes it easy to visualize which neighborhoods have the highest and lowest average prices at a glance.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - The top neighborhoods in NYC based on average price per day are Willowbrook, Neponsit, and Breezy Point, each with average daily prices above $200. These neighborhoods are likely located in areas where there is high demand for specific types of accommodations, possibly due to exclusivity or luxury.
# - Other popular and well-known areas like Tribeca, NoHo, and West Village also have relatively high average prices, ranging between $200 and $230 per day.
# - Greenwich Village, Midtown, and the Financial District have slightly lower average prices, around $150–$175 per day, though these are still high compared to other parts of NYC.
# - The chart reveals that some lesser-known neighborhoods have even higher average prices than iconic neighborhoods, which might suggest specific local factors like property type, demand, or proximity to certain amenities.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, these insights are valuable for both hosts and property managers looking to optimize their pricing strategies:
# - Hosts in high-price neighborhoods like Willowbrook or Neponsit should capitalize on this pricing advantage by maintaining premium services and amenities to justify these higher rates. They could also promote their properties as exclusive or high-end, especially if the area is known for luxury accommodations.
# - Competitive pricing: In areas like Midtown or the Financial District, where prices are slightly lower, hosts might face more competition. Hosts in these areas should consider differentiating their listings through unique experiences or additional amenities, rather than competing solely on price.
# - Growth opportunities: Property managers or investors looking to enter the NYC market can use these insights to identify neighborhoods where high prices per day can be sustained. Additionally, neighborhoods with relatively lower prices (e.g., Greenwich Village) may offer opportunities for further investment, as the demand could still be strong but prices may not have peaked yet.

# %% [markdown]
# #### Chart 10

# %%
reviews_per_month = df_without_outliers.groupby('host_id')['number_of_reviews'].sum().reset_index().sort_values(by='number_of_reviews', ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x= reviews_per_month['host_id'], y=reviews_per_month['number_of_reviews'])
plt.title('Top 10 Reviewed Hosts by Reviews')
plt.xlabel('Reviews/Month')
plt.ylabel('Host ID')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it effectively displays the top 10 reviewed hosts by the number of reviews per month. This chart type is well-suited for comparing discrete categories (Host IDs) against a numerical value (number of reviews per month). It allows for easy comparison of the review counts across multiple hosts, helping us quickly identify the most active and highly reviewed hosts.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - The host with ID 344035 has the highest number of reviews per month, with over 2,000 reviews. This suggests that this host is managing a large number of properties or has highly engaged guests.
# - Other hosts, such as 26432133 and 37312959, also have high review counts, close to 1,800 reviews per month.
# - There is some variation in the number of reviews among the top 10 hosts, but all of them have at least 1,000 reviews per month, indicating a high level of guest engagement and activity on their listings.
# - These top-reviewed hosts are likely managing a large number of properties or providing consistently high-quality service that encourages guests to leave reviews.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, these insights can help create a positive business impact in the following ways:
# - Host Benchmarking: Other hosts can use these top-reviewed hosts as benchmarks. By studying the practices of these highly reviewed hosts (such as guest communication, property management, and guest satisfaction strategies), newer or less-reviewed hosts can adopt best practices to improve their own review counts.
# - Reputation Building: Reviews are critical for boosting a host's visibility and credibility on Airbnb. Understanding that these hosts are receiving a large number of reviews can encourage other hosts to focus on guest experience and incentivizing reviews to increase their own visibility and rankings.
# - Potential Collaboration: Property managers and investors may want to explore partnerships or collaborations with these highly active hosts to learn from their strategies or offer services to help manage high-demand listings.
# - Business Expansion Opportunities: The hosts with consistently high reviews are likely managing multiple properties, suggesting that successful hosts might be expanding their portfolios. Other hosts who are thinking about scaling their operations can look to these top hosts for guidance on how to manage a larger number of properties while maintaining high levels of guest satisfaction.

# %% [markdown]
# #### Chart 11

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='longitude', y='latitude', hue='neighbourhood_group', data=df_without_outliers)
plt.title('Neighborhood Groups by Latitude and Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Neighborhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen because it is effective in visualizing the geographical distribution of Airbnb listings based on their latitude and longitude. Each dot represents a listing, and the color grouping allows us to easily differentiate between the various neighborhood groups (Brooklyn, Manhattan, Queens, Staten Island, and Bronx). This type of chart is excellent for showing spatial relationships and clustering of listings across different areas of New York City.

# %% [markdown]
# ##### 2. What are the insights found from the chart?

# %% [markdown]
# - Geographical clustering: The listings are clearly clustered by neighborhood group. Each neighborhood is distinctly separated, showing that the Airbnb listings are mostly concentrated within the boundaries of their respective areas.
# - Density of listings: Manhattan and Brooklyn appear to have the highest density of listings compared to the other boroughs, suggesting that these areas are more popular for Airbnb properties.
# - Bronx and Staten Island: These boroughs have fewer listings, especially Staten Island, which has the smallest concentration of Airbnb properties. This could indicate lower demand or fewer property - owners listing their spaces on Airbnb in these areas.
# - Geographical spread: Listings in Queens and Brooklyn cover a broader geographic area compared to Manhattan, where listings are more tightly concentrated.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes, the insights from this chart can help Airbnb hosts, property managers, and potential investors make more informed decisions:
# - Targeting high-demand areas: Since Manhattan and Brooklyn have the highest density of listings, hosts in these areas need to be aware of the competition and find ways to differentiate their properties (e.g., offering unique amenities, better pricing strategies, or improved guest experiences) to stand out.
# - Growth opportunities: The relatively lower number of listings in Staten Island and the Bronx could indicate potential growth opportunities. Hosts who list properties in these areas may face less competition and could attract guests looking for more affordable options compared to pricier Manhattan or Brooklyn listings.
# - Localized marketing: Hosts can tailor their marketing efforts based on the geographical clustering of listings. For instance, in Queens, where there is a broader spread of listings, marketing could focus on specific neighborhoods or proximity to transport hubs, while in tightly packed areas like Manhattan, hosts may emphasize the convenience of central locations.
